# %%
#worked locally but fails when ecountering duplicates
import os
import pandas as pd
import cx_Oracle
from datetime import datetime
import glob

# Oracle Database connection details
# DB_USER = "system"
# DB_PASSWORD = "oracle"
# DB_HOST = "localhost"
# DB_PORT = "1521"
# DB_SERVICE_NAME = "XE"
DB_USER = "EDI"
DB_PASSWORD = "edi"
DB_HOST = "172.16.2.122"
DB_PORT = "1521"
DB_SERVICE_NAME = "EDIPROD"
TABLE_NAME = "ITRS_URT_RECEIPTS"

# Directory path containing the .xls files
FILE_PATH = r"C:\edi_data\test"  # Update with your actual file path

# Expected DataFrame columns (adapt this to your actual columns)
COLUMNS = ['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY', 'AMOUNT', 'DESCRIPTION']

# Function to create the connection and perform insertion
def create_db_connection():
    # Oracle DSN (Data Source Name)
    dsn = cx_Oracle.makedsn(DB_HOST, DB_PORT, service_name=DB_SERVICE_NAME)
    
    # Establishing the connection
    connection = cx_Oracle.connect(DB_USER, DB_PASSWORD, dsn)
    return connection

# Function to insert/update data from DataFrame
# def upsert_data(df, connection):
#     cursor = connection.cursor()
    
#     # Insert SQL statement for the ITRS_URT_RECEIPTS table
#     insert_sql = """
#         INSERT INTO ITRS_URT_RECEIPTS (INSTITUTIONCODE, REPORTINGDATE, DESCRIPTIONNO, PURPOSE, PU_CODE, 
#                                        COUNTRY, SECTOR, CURRENCY, AMOUNT, DESCRIPTION, STATUS)
#         VALUES (:INSTITUTIONCODE, TO_DATE(:REPORTINGDATE, 'DD-MON-YYYY'), :DESCRIPTIONNO, :PURPOSE, :PU_CODE, 
#                 :COUNTRY, :SECTOR, :CURRENCY, :AMOUNT, :DESCRIPTION, :STATUS)
#     """
    
#     # Iterating through DataFrame rows and executing insert query
#     for _, row in df.iterrows():
#         cursor.execute(insert_sql, row.to_dict())
    
#     # Commit the transaction
#     connection.commit()
#     cursor.close()
import cx_Oracle
import pandas as pd

def upsert_data(df, connection):
    cursor = connection.cursor()
    
    # Convert data types to match the table definition
    df = df.fillna('')
    df['REPORTINGDATE'] = pd.to_datetime(df['REPORTINGDATE'], errors='coerce').dt.strftime('%d-%b-%Y')  # Format as 'DD-MON-YYYY'
    
    # Ensure numeric columns are converted properly
    df['DESCRIPTIONNO'] = pd.to_numeric(df['DESCRIPTIONNO'], errors='coerce').fillna(0).astype(int)  # Convert to int
    df['PU_CODE'] = pd.to_numeric(df['PU_CODE'], errors='coerce').fillna(0).astype(int)  # Convert to int
    df['AMOUNT'] = pd.to_numeric(df['AMOUNT'], errors='coerce').fillna(0).astype(float)  # Convert to float
    
    # Convert DataFrame rows to list of tuples
    data_tuples = [
        (
            row.INSTITUTIONCODE, row.REPORTINGDATE, row.DESCRIPTIONNO, row.PURPOSE, row.PU_CODE,
            row.COUNTRY, row.SECTOR, row.CURRENCY, row.AMOUNT, row.DESCRIPTION, row.STATUS
        )
        for _, row in df.iterrows()
    ]
    
    # UPSERT (MERGE) SQL statement
    upsert_sql = """
        MERGE INTO ITRS_URT_RECEIPTS target
        USING (SELECT :1 AS INSTITUTIONCODE, TO_DATE(:2, 'DD-MON-YYYY') AS REPORTINGDATE, :3 AS DESCRIPTIONNO, 
                      :4 AS PURPOSE, :5 AS PU_CODE, :6 AS COUNTRY, :7 AS SECTOR, :8 AS CURRENCY, 
                      :9 AS AMOUNT, :10 AS DESCRIPTION, :11 AS STATUS FROM DUAL) source
        ON (target.INSTITUTIONCODE = source.INSTITUTIONCODE AND target.REPORTINGDATE = source.REPORTINGDATE AND 
            target.DESCRIPTIONNO = source.DESCRIPTIONNO)
        WHEN MATCHED THEN 
            UPDATE SET target.PURPOSE = source.PURPOSE, target.PU_CODE = source.PU_CODE, 
                       target.COUNTRY = source.COUNTRY, target.SECTOR = source.SECTOR, 
                       target.CURRENCY = source.CURRENCY, target.AMOUNT = source.AMOUNT, 
                       target.DESCRIPTION = source.DESCRIPTION, target.STATUS = source.STATUS
        WHEN NOT MATCHED THEN 
            INSERT (INSTITUTIONCODE, REPORTINGDATE, DESCRIPTIONNO, PURPOSE, PU_CODE, 
                    COUNTRY, SECTOR, CURRENCY, AMOUNT, DESCRIPTION, STATUS)
            VALUES (source.INSTITUTIONCODE, source.REPORTINGDATE, source.DESCRIPTIONNO, source.PURPOSE, 
                    source.PU_CODE, source.COUNTRY, source.SECTOR, source.CURRENCY, 
                    source.AMOUNT, source.DESCRIPTION, source.STATUS)
    """

    try:
        cursor.executemany(upsert_sql, data_tuples)  # Bulk UPSERT for efficiency
        connection.commit()
        print(f"Upserted {len(data_tuples)} records successfully.")
    except cx_Oracle.DatabaseError as e:
        print(f"Database error: {e}")
      


# Function to read and process .xls files from directory
def read_data_from_file(file):
    # Extract institution code and reporting date from the filename
    file_name = os.path.basename(file)
    institution_code = ""
    reporting_date_str = ""

    print(f"file: {file}")
    print(f"file_name: {file_name}")
    


    # Extract reporting date from file name (assumes position of date is fixed in the filename)
    try:
        # Assuming reporting date is at positions 8-13 (e.g., '831012' for date 08/31/2012)
        filename = file.split("\\")[-1]

        # Extract institution code (assuming it is the first 4 characters)
        institution_code = filename[:4]
        reporting_date_str = filename[8:14]
         
        print(f"Extracted reporting date string: {reporting_date_str} {institution_code}")
        reporting_date = datetime.strptime(reporting_date_str, '%d%m%y').strftime('%d-%b-%Y')  # Format to DD-MON-YYYY
        print(f"Formatted reporting date: {reporting_date}")
    except ValueError:
        print(f"Invalid reporting date format in file: {file_name}")
        return None


    # Read the Excel file into a DataFrame
    normalized_file_name = os.path.normpath(file)
    print(f"Normalized file path: {normalized_file_name}")
    if not os.path.exists(normalized_file_name):
        print(f"File not found: {normalized_file_name}")
        return None
    
    df = pd.read_excel(normalized_file_name, 
                       engine='xlrd',
                       sheet_name='ITRS2_URT_RECEIPTS', 
                       usecols="A:H",
                       skiprows=7,   
                       names=COLUMNS)
    # Filter rows where columns PURPOSE to DESCRIPTION are not empty or null
    df = df.dropna(subset=['PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY', 'AMOUNT', 'DESCRIPTION'])

    
    #print(df.head(3))
    df['REPORTINGDATE']  =  datetime.strptime(reporting_date_str, '%d%m%y').strftime('%Y-%m-%d')
    df['STATUS'] = 'N'
    # Data preprocessing: Convert date to correct format and fill missing values if necessary
    df['REPORTINGDATE'] = pd.to_datetime(df['REPORTINGDATE'], errors='coerce').dt.strftime('%d-%b-%Y')  # Format to DD-MON-YYYY
    df['STATUS'] = df['STATUS'].fillna('N')  # Default to 'N' if STATUS is missing
    
    # Add institution code and reporting date from the filename
    df['INSTITUTIONCODE'] = institution_code
    #df['REPORTINGDATE'] = reporting_date
    df = df.rename(columns=lambda x: x.strip().upper())
    #print(df.head(2))
    print(df.columns)
    return df


# Main function to orchestrate the process
def main():
    # Create connection to the Oracle database
    connection = create_db_connection()
    filex = ""
    try:
        # Iterate through all .xls files in the specified directory
        for filex in glob.glob(os.path.join(FILE_PATH, "*.xls")):
            print(f"Processing file: {filex}")
            
            # Read and preprocess data from the Excel file
            df = read_data_from_file(filex)

            if df is not None:
                # Insert data into the database
                upsert_data(df, connection)
                print(f"Data inserted/updated successfully from file: {filex}")  
    except Exception as e:
        print(f"Error occurred: {e}")
    
    finally:
        # Close the connection to the database
        connection.close()

if __name__ == "__main__":
    main()
# Out:
# Processing file: C:\edi_data\test\A1241078310124.xls
# file: C:\edi_data\test\A1241078310124.xls
# file_name: A1241078310124.xls
# Extracted reporting date string: 310124 A124
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1241078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 263 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078310124.xls
# Processing file: C:\edi_data\test\A1251078310124.xls
# file: C:\edi_data\test\A1251078310124.xls
# file_name: A1251078310124.xls
# Extracted reporting date string: 310124 A125
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1251078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Database error: ORA-00001: unique constraint (EDI.PK_ITRS_URT_RECEIPTS) violated
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078310124.xls
# Processing file: C:\edi_data\test\A1281078310124.xls
# file: C:\edi_data\test\A1281078310124.xls
# file_name: A1281078310124.xls
# Extracted reporting date string: 310124 A128
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1281078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Database error: ORA-00001: unique constraint (EDI.PK_ITRS_URT_RECEIPTS) violated
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078310124.xls
# Processing file: C:\edi_data\test\A1291078310124.xls
# file: C:\edi_data\test\A1291078310124.xls
# file_name: A1291078310124.xls
# Extracted reporting date string: 310124 A129
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1291078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')

# %%
print("running")
# Out:
# running

# %%
#fixing duplicate issues, improved version
import os
import pandas as pd
import cx_Oracle
from datetime import datetime
import glob

# Oracle Database connection details
# DB_USER = "system"
# DB_PASSWORD = "oracle"
# DB_HOST = "localhost"
# DB_PORT = "1521"
# DB_SERVICE_NAME = "XE"
DB_USER = "EDI"
DB_PASSWORD = "edi"
DB_HOST = "127.0.0.1"  #"172.16.2.122"
DB_PORT = "1521"
DB_SERVICE_NAME = "XE" #"EDIPROD"
TABLE_NAME = "ITRS_URT_RECEIPTS"

# Directory path containing the .xls files
FILE_PATH = r"C:\edi_data\test"  # Update with your actual file path

# Expected DataFrame columns (adapt this to your actual columns)
COLUMNS = ['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY', 'AMOUNT', 'DESCRIPTION']

# Function to create the connection and perform insertion
def create_db_connection():
    # Oracle DSN (Data Source Name)
    dsn = cx_Oracle.makedsn(DB_HOST, DB_PORT, service_name=DB_SERVICE_NAME)
    
    # Establishing the connection
    connection = cx_Oracle.connect(DB_USER, DB_PASSWORD, dsn)
    return connection

# Function to insert/update data from DataFrame
# def upsert_data(df, connection):
#     cursor = connection.cursor()
    
#     # Insert SQL statement for the ITRS_URT_RECEIPTS table
#     insert_sql = """
#         INSERT INTO ITRS_URT_RECEIPTS (INSTITUTIONCODE, REPORTINGDATE, DESCRIPTIONNO, PURPOSE, PU_CODE, 
#                                        COUNTRY, SECTOR, CURRENCY, AMOUNT, DESCRIPTION, STATUS)
#         VALUES (:INSTITUTIONCODE, TO_DATE(:REPORTINGDATE, 'DD-MON-YYYY'), :DESCRIPTIONNO, :PURPOSE, :PU_CODE, 
#                 :COUNTRY, :SECTOR, :CURRENCY, :AMOUNT, :DESCRIPTION, :STATUS)
#     """
    
#     # Iterating through DataFrame rows and executing insert query
#     for _, row in df.iterrows():
#         cursor.execute(insert_sql, row.to_dict())
    
#     # Commit the transaction
#     connection.commit()
#     cursor.close()
import cx_Oracle
import pandas as pd

def upsert_data(df, connection):
    cursor = connection.cursor()
    
    df = df.fillna('')
    df['REPORTINGDATE'] = pd.to_datetime(df['REPORTINGDATE'], errors='coerce').dt.strftime('%d-%b-%Y')
    
    df['DESCRIPTIONNO'] = pd.to_numeric(df['DESCRIPTIONNO'], errors='coerce').fillna(0).astype(int)
    df['PU_CODE'] = pd.to_numeric(df['PU_CODE'], errors='coerce').fillna(0).astype(int)
    df['AMOUNT'] = pd.to_numeric(df['AMOUNT'], errors='coerce').fillna(0).astype(float)

    upsert_sql = """
        MERGE INTO ITRS_URT_RECEIPTS target
        USING (SELECT :1 AS INSTITUTIONCODE, TO_DATE(:2, 'DD-MON-YYYY') AS REPORTINGDATE, :3 AS DESCRIPTIONNO, 
                      :4 AS PURPOSE, :5 AS PU_CODE, :6 AS COUNTRY, :7 AS SECTOR, :8 AS CURRENCY, 
                      :9 AS AMOUNT, :10 AS DESCRIPTION, :11 AS STATUS FROM DUAL) source
        ON (target.INSTITUTIONCODE = source.INSTITUTIONCODE AND target.REPORTINGDATE = source.REPORTINGDATE AND 
            target.DESCRIPTIONNO = source.DESCRIPTIONNO)
        WHEN MATCHED THEN 
            UPDATE SET target.PURPOSE = source.PURPOSE, target.PU_CODE = source.PU_CODE, 
                       target.COUNTRY = source.COUNTRY, target.SECTOR = source.SECTOR, 
                       target.CURRENCY = source.CURRENCY, target.AMOUNT = source.AMOUNT, 
                       target.DESCRIPTION = source.DESCRIPTION, target.STATUS = source.STATUS
        WHEN NOT MATCHED THEN 
            INSERT (INSTITUTIONCODE, REPORTINGDATE, DESCRIPTIONNO, PURPOSE, PU_CODE, 
                    COUNTRY, SECTOR, CURRENCY, AMOUNT, DESCRIPTION, STATUS)
            VALUES (source.INSTITUTIONCODE, source.REPORTINGDATE, source.DESCRIPTIONNO, source.PURPOSE, 
                    source.PU_CODE, source.COUNTRY, source.SECTOR, source.CURRENCY, 
                    source.AMOUNT, source.DESCRIPTION, source.STATUS)
    """
    duplicate_records = 0
    upserted_records = 0
    for _, row in df.iterrows():
        duplicate_records = 0
        inserted_records = 0
        try:
            cursor.execute(upsert_sql, (
                row.INSTITUTIONCODE, row.REPORTINGDATE, row.DESCRIPTIONNO, row.PURPOSE, row.PU_CODE,
                row.COUNTRY, row.SECTOR, row.CURRENCY, row.AMOUNT, row.DESCRIPTION, row.STATUS
            ))
            upserted_records += 1
        except cx_Oracle.IntegrityError as e:
            #print(f"Skipping duplicate entry: {row.DESCRIPTIONNO} - {e}")
            duplicate_records += 1
        except cx_Oracle.DatabaseError as e:
            print(f"Database error on {row.DESCRIPTIONNO}: {e}")
    
    connection.commit()
    print(f"Upserted {upserted_records} records successfully.")
    cursor.close()


# Function to read and process .xls files from directory
def read_data_from_file(file):
    # Extract institution code and reporting date from the filename
    file_name = os.path.basename(file)
    institution_code = ""
    reporting_date_str = ""

    print(f"file: {file}")
    print(f"file_name: {file_name}")
    


    # Extract reporting date from file name (assumes position of date is fixed in the filename)
    try:
        # Assuming reporting date is at positions 8-13 (e.g., '831012' for date 08/31/2012)
        filename = file.split("\\")[-1]

        # Extract institution code (assuming it is the first 4 characters)
        institution_code = filename[:4]
        reporting_date_str = filename[8:14]
         
        print(f"Extracted reporting date string: {reporting_date_str} {institution_code}")
        reporting_date = datetime.strptime(reporting_date_str, '%d%m%y').strftime('%d-%b-%Y')  # Format to DD-MON-YYYY
        print(f"Formatted reporting date: {reporting_date}")
    except ValueError:
        print(f"Invalid reporting date format in file: {file_name}")
        return None


    # Read the Excel file into a DataFrame
    normalized_file_name = os.path.normpath(file)
    print(f"Normalized file path: {normalized_file_name}")
    if not os.path.exists(normalized_file_name):
        print(f"File not found: {normalized_file_name}")
        return None
    
    df = pd.read_excel(normalized_file_name, 
                       engine='xlrd',
                       sheet_name='ITRS2_URT_RECEIPTS', 
                       usecols="A:H",
                       skiprows=7,   
                       names=COLUMNS)
    # Filter rows where columns PURPOSE to DESCRIPTION are not empty or null
    df = df.dropna(subset=['PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY', 'AMOUNT', 'DESCRIPTION'])

    
    #print(df.head(3))
    df['REPORTINGDATE']  =  datetime.strptime(reporting_date_str, '%d%m%y').strftime('%Y-%m-%d')
    df['STATUS'] = 'N'
    # Data preprocessing: Convert date to correct format and fill missing values if necessary
    df['REPORTINGDATE'] = pd.to_datetime(df['REPORTINGDATE'], errors='coerce').dt.strftime('%d-%b-%Y')  # Format to DD-MON-YYYY
    df['STATUS'] = df['STATUS'].fillna('N')  # Default to 'N' if STATUS is missing
    
    # Add institution code and reporting date from the filename
    df['INSTITUTIONCODE'] = institution_code
    #df['REPORTINGDATE'] = reporting_date
    df = df.rename(columns=lambda x: x.strip().upper())
    #print(df.head(2))
    print(df.columns)
    return df


# Main function to orchestrate the process
def main():
    # Create connection to the Oracle database
    connection = create_db_connection()
    filex = ""
    try:
        # Iterate through all .xls files in the specified directory
        for filex in glob.glob(os.path.join(FILE_PATH, "*.xls")):
            print(f"Processing file: {filex}")
            
            # Read and preprocess data from the Excel file
            df = read_data_from_file(filex)

            if df is not None:
                # Insert data into the database
                upsert_data(df, connection)
                print(f"Data inserted/updated successfully from file: {filex}")  
    except Exception as e:
        print(f"Error occurred: {e}")
    
    finally:
        # Close the connection to the database
        connection.close()

if __name__ == "__main__":
    main()
# Out:
# Processing file: C:\edi_data\test\A1241078290224.xls
# file: C:\edi_data\test\A1241078290224.xls
# file_name: A1241078290224.xls
# Extracted reporting date string: 290224 A124
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1241078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 258 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078290224.xls
# Processing file: C:\edi_data\test\A1241078300424.xls
# file: C:\edi_data\test\A1241078300424.xls
# file_name: A1241078300424.xls
# Extracted reporting date string: 300424 A124
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1241078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 235 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078300424.xls
# Processing file: C:\edi_data\test\A1241078300624.xls
# file: C:\edi_data\test\A1241078300624.xls
# file_name: A1241078300624.xls
# Extracted reporting date string: 300624 A124
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1241078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 264 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078300624.xls
# Processing file: C:\edi_data\test\A1241078300924.xls
# file: C:\edi_data\test\A1241078300924.xls
# file_name: A1241078300924.xls
# Extracted reporting date string: 300924 A124
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1241078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 262 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078300924.xls
# Processing file: C:\edi_data\test\A1241078301124.xls
# file: C:\edi_data\test\A1241078301124.xls
# file_name: A1241078301124.xls
# Extracted reporting date string: 301124 A124
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1241078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 244 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078301124.xls
# Processing file: C:\edi_data\test\A1241078310124.xls
# file: C:\edi_data\test\A1241078310124.xls
# file_name: A1241078310124.xls
# Extracted reporting date string: 310124 A124
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1241078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 263 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078310124.xls
# Processing file: C:\edi_data\test\A1241078310324.xls
# file: C:\edi_data\test\A1241078310324.xls
# file_name: A1241078310324.xls
# Extracted reporting date string: 310324 A124
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1241078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 248 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078310324.xls
# Processing file: C:\edi_data\test\A1241078310524.xls
# file: C:\edi_data\test\A1241078310524.xls
# file_name: A1241078310524.xls
# Extracted reporting date string: 310524 A124
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1241078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 306 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078310524.xls
# Processing file: C:\edi_data\test\A1241078310724.xls
# file: C:\edi_data\test\A1241078310724.xls
# file_name: A1241078310724.xls
# Extracted reporting date string: 310724 A124
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1241078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 290 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078310724.xls
# Processing file: C:\edi_data\test\A1241078310824.xls
# file: C:\edi_data\test\A1241078310824.xls
# file_name: A1241078310824.xls
# Extracted reporting date string: 310824 A124
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1241078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 230 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078310824.xls
# Processing file: C:\edi_data\test\A1241078311024.xls
# file: C:\edi_data\test\A1241078311024.xls
# file_name: A1241078311024.xls
# Extracted reporting date string: 311024 A124
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1241078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 262 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078311024.xls
# Processing file: C:\edi_data\test\A1241078311224.xls
# file: C:\edi_data\test\A1241078311224.xls
# file_name: A1241078311224.xls
# Extracted reporting date string: 311224 A124
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1241078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 240 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1241078311224.xls
# Processing file: C:\edi_data\test\A1251078290224.xls
# file: C:\edi_data\test\A1251078290224.xls
# file_name: A1251078290224.xls
# Extracted reporting date string: 290224 A125
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1251078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 613 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078290224.xls
# Processing file: C:\edi_data\test\A1251078300424.xls
# file: C:\edi_data\test\A1251078300424.xls
# file_name: A1251078300424.xls
# Extracted reporting date string: 300424 A125
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1251078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 402 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078300424.xls
# Processing file: C:\edi_data\test\A1251078300624.xls
# file: C:\edi_data\test\A1251078300624.xls
# file_name: A1251078300624.xls
# Extracted reporting date string: 300624 A125
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1251078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 1326 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078300624.xls
# Processing file: C:\edi_data\test\A1251078300924.xls
# file: C:\edi_data\test\A1251078300924.xls
# file_name: A1251078300924.xls
# Extracted reporting date string: 300924 A125
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1251078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 5661 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078300924.xls
# Processing file: C:\edi_data\test\A1251078301124.xls
# file: C:\edi_data\test\A1251078301124.xls
# file_name: A1251078301124.xls
# Extracted reporting date string: 301124 A125
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1251078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 5129 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078301124.xls
# Processing file: C:\edi_data\test\A1251078310124.xls
# file: C:\edi_data\test\A1251078310124.xls
# file_name: A1251078310124.xls
# Extracted reporting date string: 310124 A125
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1251078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 921 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078310124.xls
# Processing file: C:\edi_data\test\A1251078310324.xls
# file: C:\edi_data\test\A1251078310324.xls
# file_name: A1251078310324.xls
# Extracted reporting date string: 310324 A125
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1251078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 1192 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078310324.xls
# Processing file: C:\edi_data\test\A1251078310524.xls
# file: C:\edi_data\test\A1251078310524.xls
# file_name: A1251078310524.xls
# Extracted reporting date string: 310524 A125
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1251078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 402 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078310524.xls
# Processing file: C:\edi_data\test\A1251078310724.xls
# file: C:\edi_data\test\A1251078310724.xls
# file_name: A1251078310724.xls
# Extracted reporting date string: 310724 A125
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1251078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 1326 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078310724.xls
# Processing file: C:\edi_data\test\A1251078310824.xls
# file: C:\edi_data\test\A1251078310824.xls
# file_name: A1251078310824.xls
# Extracted reporting date string: 310824 A125
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1251078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 7697 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078310824.xls
# Processing file: C:\edi_data\test\A1251078311024.xls
# file: C:\edi_data\test\A1251078311024.xls
# file_name: A1251078311024.xls
# Extracted reporting date string: 311024 A125
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1251078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 7449 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078311024.xls
# Processing file: C:\edi_data\test\A1251078311224.xls
# file: C:\edi_data\test\A1251078311224.xls
# file_name: A1251078311224.xls
# Extracted reporting date string: 311224 A125
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1251078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 5515 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1251078311224.xls
# Processing file: C:\edi_data\test\A1281078290224.xls
# file: C:\edi_data\test\A1281078290224.xls
# file_name: A1281078290224.xls
# Extracted reporting date string: 290224 A128
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1281078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 299 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078290224.xls
# Processing file: C:\edi_data\test\A1281078300424.xls
# file: C:\edi_data\test\A1281078300424.xls
# file_name: A1281078300424.xls
# Extracted reporting date string: 300424 A128
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1281078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 291 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078300424.xls
# Processing file: C:\edi_data\test\A1281078300624.xls
# file: C:\edi_data\test\A1281078300624.xls
# file_name: A1281078300624.xls
# Extracted reporting date string: 300624 A128
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1281078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 502 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078300624.xls
# Processing file: C:\edi_data\test\A1281078300924.xls
# file: C:\edi_data\test\A1281078300924.xls
# file_name: A1281078300924.xls
# Extracted reporting date string: 300924 A128
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1281078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 545 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078300924.xls
# Processing file: C:\edi_data\test\A1281078301124.xls
# file: C:\edi_data\test\A1281078301124.xls
# file_name: A1281078301124.xls
# Extracted reporting date string: 301124 A128
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1281078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 468 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078301124.xls
# Processing file: C:\edi_data\test\A1281078310124.xls
# file: C:\edi_data\test\A1281078310124.xls
# file_name: A1281078310124.xls
# Extracted reporting date string: 310124 A128
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1281078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 451 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078310124.xls
# Processing file: C:\edi_data\test\A1281078310324.xls
# file: C:\edi_data\test\A1281078310324.xls
# file_name: A1281078310324.xls
# Extracted reporting date string: 310324 A128
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1281078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 359 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078310324.xls
# Processing file: C:\edi_data\test\A1281078310524.xls
# file: C:\edi_data\test\A1281078310524.xls
# file_name: A1281078310524.xls
# Extracted reporting date string: 310524 A128
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1281078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 449 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078310524.xls
# Processing file: C:\edi_data\test\A1281078310724.xls
# file: C:\edi_data\test\A1281078310724.xls
# file_name: A1281078310724.xls
# Extracted reporting date string: 310724 A128
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1281078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 546 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078310724.xls
# Processing file: C:\edi_data\test\A1281078310824.xls
# file: C:\edi_data\test\A1281078310824.xls
# file_name: A1281078310824.xls
# Extracted reporting date string: 310824 A128
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1281078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 456 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078310824.xls
# Processing file: C:\edi_data\test\A1281078311024.xls
# file: C:\edi_data\test\A1281078311024.xls
# file_name: A1281078311024.xls
# Extracted reporting date string: 311024 A128
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1281078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 456 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078311024.xls
# Processing file: C:\edi_data\test\A1281078311224.xls
# file: C:\edi_data\test\A1281078311224.xls
# file_name: A1281078311224.xls
# Extracted reporting date string: 311224 A128
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1281078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 469 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1281078311224.xls
# Processing file: C:\edi_data\test\A1291078290224.xls
# file: C:\edi_data\test\A1291078290224.xls
# file_name: A1291078290224.xls
# Extracted reporting date string: 290224 A129
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1291078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 10754 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078290224.xls
# Processing file: C:\edi_data\test\A1291078300424.xls
# file: C:\edi_data\test\A1291078300424.xls
# file_name: A1291078300424.xls
# Extracted reporting date string: 300424 A129
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1291078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 9746 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078300424.xls
# Processing file: C:\edi_data\test\A1291078300624.xls
# file: C:\edi_data\test\A1291078300624.xls
# file_name: A1291078300624.xls
# Extracted reporting date string: 300624 A129
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1291078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 11263 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078300624.xls
# Processing file: C:\edi_data\test\A1291078300924.xls
# file: C:\edi_data\test\A1291078300924.xls
# file_name: A1291078300924.xls
# Extracted reporting date string: 300924 A129
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1291078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 13357 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078300924.xls
# Processing file: C:\edi_data\test\A1291078301124.xls
# file: C:\edi_data\test\A1291078301124.xls
# file_name: A1291078301124.xls
# Extracted reporting date string: 301124 A129
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1291078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 12874 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078301124.xls
# Processing file: C:\edi_data\test\A1291078310124.xls
# file: C:\edi_data\test\A1291078310124.xls
# file_name: A1291078310124.xls
# Extracted reporting date string: 310124 A129
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1291078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 11632 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078310124.xls
# Processing file: C:\edi_data\test\A1291078310324.xls
# file: C:\edi_data\test\A1291078310324.xls
# file_name: A1291078310324.xls
# Extracted reporting date string: 310324 A129
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1291078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 11006 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078310324.xls
# Processing file: C:\edi_data\test\A1291078310524.xls
# file: C:\edi_data\test\A1291078310524.xls
# file_name: A1291078310524.xls
# Extracted reporting date string: 310524 A129
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1291078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 11168 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078310524.xls
# Processing file: C:\edi_data\test\A1291078310724.xls
# file: C:\edi_data\test\A1291078310724.xls
# file_name: A1291078310724.xls
# Extracted reporting date string: 310724 A129
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1291078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 13964 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078310724.xls
# Processing file: C:\edi_data\test\A1291078310824.xls
# file: C:\edi_data\test\A1291078310824.xls
# file_name: A1291078310824.xls
# Extracted reporting date string: 310824 A129
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1291078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 13552 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078310824.xls
# Processing file: C:\edi_data\test\A1291078311024.xls
# file: C:\edi_data\test\A1291078311024.xls
# file_name: A1291078311024.xls
# Extracted reporting date string: 311024 A129
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1291078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 14408 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078311024.xls
# Processing file: C:\edi_data\test\A1291078311224.xls
# file: C:\edi_data\test\A1291078311224.xls
# file_name: A1291078311224.xls
# Extracted reporting date string: 311224 A129
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1291078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 15009 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1291078311224.xls
# Processing file: C:\edi_data\test\A1321078290224.xls
# file: C:\edi_data\test\A1321078290224.xls
# file_name: A1321078290224.xls
# Extracted reporting date string: 290224 A132
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1321078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078290224.xls
# Processing file: C:\edi_data\test\A1321078300424.xls
# file: C:\edi_data\test\A1321078300424.xls
# file_name: A1321078300424.xls
# Extracted reporting date string: 300424 A132
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1321078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078300424.xls
# Processing file: C:\edi_data\test\A1321078300624.xls
# file: C:\edi_data\test\A1321078300624.xls
# file_name: A1321078300624.xls
# Extracted reporting date string: 300624 A132
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1321078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078300624.xls
# Processing file: C:\edi_data\test\A1321078300924.xls
# file: C:\edi_data\test\A1321078300924.xls
# file_name: A1321078300924.xls
# Extracted reporting date string: 300924 A132
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1321078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078300924.xls
# Processing file: C:\edi_data\test\A1321078301124.xls
# file: C:\edi_data\test\A1321078301124.xls
# file_name: A1321078301124.xls
# Extracted reporting date string: 301124 A132
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1321078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078301124.xls
# Processing file: C:\edi_data\test\A1321078310124.xls
# file: C:\edi_data\test\A1321078310124.xls
# file_name: A1321078310124.xls
# Extracted reporting date string: 310124 A132
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1321078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078310124.xls
# Processing file: C:\edi_data\test\A1321078310324.xls
# file: C:\edi_data\test\A1321078310324.xls
# file_name: A1321078310324.xls
# Extracted reporting date string: 310324 A132
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1321078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078310324.xls
# Processing file: C:\edi_data\test\A1321078310524.xls
# file: C:\edi_data\test\A1321078310524.xls
# file_name: A1321078310524.xls
# Extracted reporting date string: 310524 A132
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1321078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078310524.xls
# Processing file: C:\edi_data\test\A1321078310724.xls
# file: C:\edi_data\test\A1321078310724.xls
# file_name: A1321078310724.xls
# Extracted reporting date string: 310724 A132
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1321078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078310724.xls
# Processing file: C:\edi_data\test\A1321078310824.xls
# file: C:\edi_data\test\A1321078310824.xls
# file_name: A1321078310824.xls
# Extracted reporting date string: 310824 A132
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1321078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078310824.xls
# Processing file: C:\edi_data\test\A1321078311024.xls
# file: C:\edi_data\test\A1321078311024.xls
# file_name: A1321078311024.xls
# Extracted reporting date string: 311024 A132
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1321078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078311024.xls
# Processing file: C:\edi_data\test\A1321078311224.xls
# file: C:\edi_data\test\A1321078311224.xls
# file_name: A1321078311224.xls
# Extracted reporting date string: 311224 A132
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1321078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 0 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1321078311224.xls
# Processing file: C:\edi_data\test\A1341078290224.xls
# file: C:\edi_data\test\A1341078290224.xls
# file_name: A1341078290224.xls
# Extracted reporting date string: 290224 A134
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1341078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 101 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078290224.xls
# Processing file: C:\edi_data\test\A1341078300424.xls
# file: C:\edi_data\test\A1341078300424.xls
# file_name: A1341078300424.xls
# Extracted reporting date string: 300424 A134
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1341078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 100 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078300424.xls
# Processing file: C:\edi_data\test\A1341078300624.xls
# file: C:\edi_data\test\A1341078300624.xls
# file_name: A1341078300624.xls
# Extracted reporting date string: 300624 A134
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1341078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 91 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078300624.xls
# Processing file: C:\edi_data\test\A1341078300924.xls
# file: C:\edi_data\test\A1341078300924.xls
# file_name: A1341078300924.xls
# Extracted reporting date string: 300924 A134
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1341078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 71 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078300924.xls
# Processing file: C:\edi_data\test\A1341078301124.xls
# file: C:\edi_data\test\A1341078301124.xls
# file_name: A1341078301124.xls
# Extracted reporting date string: 301124 A134
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1341078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 73 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078301124.xls
# Processing file: C:\edi_data\test\A1341078310124.xls
# file: C:\edi_data\test\A1341078310124.xls
# file_name: A1341078310124.xls
# Extracted reporting date string: 310124 A134
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1341078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 108 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078310124.xls
# Processing file: C:\edi_data\test\A1341078310324.xls
# file: C:\edi_data\test\A1341078310324.xls
# file_name: A1341078310324.xls
# Extracted reporting date string: 310324 A134
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1341078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 105 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078310324.xls
# Processing file: C:\edi_data\test\A1341078310524.xls
# file: C:\edi_data\test\A1341078310524.xls
# file_name: A1341078310524.xls
# Extracted reporting date string: 310524 A134
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1341078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 103 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078310524.xls
# Processing file: C:\edi_data\test\A1341078310724.xls
# file: C:\edi_data\test\A1341078310724.xls
# file_name: A1341078310724.xls
# Extracted reporting date string: 310724 A134
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1341078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 108 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078310724.xls
# Processing file: C:\edi_data\test\A1341078310824.xls
# file: C:\edi_data\test\A1341078310824.xls
# file_name: A1341078310824.xls
# Extracted reporting date string: 310824 A134
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1341078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 115 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078310824.xls
# Processing file: C:\edi_data\test\A1341078311024.xls
# file: C:\edi_data\test\A1341078311024.xls
# file_name: A1341078311024.xls
# Extracted reporting date string: 311024 A134
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1341078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 86 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078311024.xls
# Processing file: C:\edi_data\test\A1341078311224.xls
# file: C:\edi_data\test\A1341078311224.xls
# file_name: A1341078311224.xls
# Extracted reporting date string: 311224 A134
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1341078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 80 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1341078311224.xls
# Processing file: C:\edi_data\test\A1361078290224.xls
# file: C:\edi_data\test\A1361078290224.xls
# file_name: A1361078290224.xls
# Extracted reporting date string: 290224 A136
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1361078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078290224.xls
# Processing file: C:\edi_data\test\A1361078300424.xls
# file: C:\edi_data\test\A1361078300424.xls
# file_name: A1361078300424.xls
# Extracted reporting date string: 300424 A136
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1361078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078300424.xls
# Processing file: C:\edi_data\test\A1361078300624.xls
# file: C:\edi_data\test\A1361078300624.xls
# file_name: A1361078300624.xls
# Extracted reporting date string: 300624 A136
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1361078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078300624.xls
# Processing file: C:\edi_data\test\A1361078300924.xls
# file: C:\edi_data\test\A1361078300924.xls
# file_name: A1361078300924.xls
# Extracted reporting date string: 300924 A136
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1361078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078300924.xls
# Processing file: C:\edi_data\test\A1361078301124.xls
# file: C:\edi_data\test\A1361078301124.xls
# file_name: A1361078301124.xls
# Extracted reporting date string: 301124 A136
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1361078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078301124.xls
# Processing file: C:\edi_data\test\A1361078310124.xls
# file: C:\edi_data\test\A1361078310124.xls
# file_name: A1361078310124.xls
# Extracted reporting date string: 310124 A136
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1361078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 17 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078310124.xls
# Processing file: C:\edi_data\test\A1361078310324.xls
# file: C:\edi_data\test\A1361078310324.xls
# file_name: A1361078310324.xls
# Extracted reporting date string: 310324 A136
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1361078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078310324.xls
# Processing file: C:\edi_data\test\A1361078310524.xls
# file: C:\edi_data\test\A1361078310524.xls
# file_name: A1361078310524.xls
# Extracted reporting date string: 310524 A136
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1361078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 17 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078310524.xls
# Processing file: C:\edi_data\test\A1361078310724.xls
# file: C:\edi_data\test\A1361078310724.xls
# file_name: A1361078310724.xls
# Extracted reporting date string: 310724 A136
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1361078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078310724.xls
# Processing file: C:\edi_data\test\A1361078310824.xls
# file: C:\edi_data\test\A1361078310824.xls
# file_name: A1361078310824.xls
# Extracted reporting date string: 310824 A136
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1361078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078310824.xls
# Processing file: C:\edi_data\test\A1361078311024.xls
# file: C:\edi_data\test\A1361078311024.xls
# file_name: A1361078311024.xls
# Extracted reporting date string: 311024 A136
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1361078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 16 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078311024.xls
# Processing file: C:\edi_data\test\A1361078311224.xls
# file: C:\edi_data\test\A1361078311224.xls
# file_name: A1361078311224.xls
# Extracted reporting date string: 311224 A136
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1361078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 15 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1361078311224.xls
# Processing file: C:\edi_data\test\A1381078290224.xls
# file: C:\edi_data\test\A1381078290224.xls
# file_name: A1381078290224.xls
# Extracted reporting date string: 290224 A138
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1381078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 37 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1381078290224.xls
# Processing file: C:\edi_data\test\A1381078300424.xls
# file: C:\edi_data\test\A1381078300424.xls
# file_name: A1381078300424.xls
# ...
#       dtype='object')
# Upserted 1 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1891078310824.xls
# Processing file: C:\edi_data\test\A1891078311024.xls
# file: C:\edi_data\test\A1891078311024.xls
# file_name: A1891078311024.xls
# Extracted reporting date string: 311024 A189
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1891078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 1 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1891078311024.xls
# Processing file: C:\edi_data\test\A1891078311224.xls
# file: C:\edi_data\test\A1891078311224.xls
# file_name: A1891078311224.xls
# Extracted reporting date string: 311224 A189
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1891078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 1 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1891078311224.xls
# Processing file: C:\edi_data\test\A1961078290224.xls
# file: C:\edi_data\test\A1961078290224.xls
# file_name: A1961078290224.xls
# Extracted reporting date string: 290224 A196
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1961078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 19 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078290224.xls
# Processing file: C:\edi_data\test\A1961078300424.xls
# file: C:\edi_data\test\A1961078300424.xls
# file_name: A1961078300424.xls
# Extracted reporting date string: 300424 A196
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1961078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 11 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078300424.xls
# Processing file: C:\edi_data\test\A1961078300624.xls
# file: C:\edi_data\test\A1961078300624.xls
# file_name: A1961078300624.xls
# Extracted reporting date string: 300624 A196
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1961078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 10 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078300624.xls
# Processing file: C:\edi_data\test\A1961078300924.xls
# file: C:\edi_data\test\A1961078300924.xls
# file_name: A1961078300924.xls
# Extracted reporting date string: 300924 A196
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1961078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 11 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078300924.xls
# Processing file: C:\edi_data\test\A1961078301124.xls
# file: C:\edi_data\test\A1961078301124.xls
# file_name: A1961078301124.xls
# Extracted reporting date string: 301124 A196
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1961078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 7 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078301124.xls
# Processing file: C:\edi_data\test\A1961078310124.xls
# file: C:\edi_data\test\A1961078310124.xls
# file_name: A1961078310124.xls
# Extracted reporting date string: 310124 A196
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1961078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 17 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078310124.xls
# Processing file: C:\edi_data\test\A1961078310324.xls
# file: C:\edi_data\test\A1961078310324.xls
# file_name: A1961078310324.xls
# Extracted reporting date string: 310324 A196
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1961078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 18 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078310324.xls
# Processing file: C:\edi_data\test\A1961078310524.xls
# file: C:\edi_data\test\A1961078310524.xls
# file_name: A1961078310524.xls
# Extracted reporting date string: 310524 A196
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1961078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 14 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078310524.xls
# Processing file: C:\edi_data\test\A1961078310724.xls
# file: C:\edi_data\test\A1961078310724.xls
# file_name: A1961078310724.xls
# Extracted reporting date string: 310724 A196
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1961078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 10 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078310724.xls
# Processing file: C:\edi_data\test\A1961078310824.xls
# file: C:\edi_data\test\A1961078310824.xls
# file_name: A1961078310824.xls
# Extracted reporting date string: 310824 A196
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1961078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 11 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078310824.xls
# Processing file: C:\edi_data\test\A1961078311024.xls
# file: C:\edi_data\test\A1961078311024.xls
# file_name: A1961078311024.xls
# Extracted reporting date string: 311024 A196
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1961078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 8 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1961078311024.xls
# Processing file: C:\edi_data\test\A1991078290224.xls
# file: C:\edi_data\test\A1991078290224.xls
# file_name: A1991078290224.xls
# Extracted reporting date string: 290224 A199
# Formatted reporting date: 29-Feb-2024
# Normalized file path: C:\edi_data\test\A1991078290224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 75 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078290224.xls
# Processing file: C:\edi_data\test\A1991078300424.xls
# file: C:\edi_data\test\A1991078300424.xls
# file_name: A1991078300424.xls
# Extracted reporting date string: 300424 A199
# Formatted reporting date: 30-Apr-2024
# Normalized file path: C:\edi_data\test\A1991078300424.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Database error on 57: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 137, maximum: 130)
# Database error on 78: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 139, maximum: 130)
# Upserted 94 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078300424.xls
# Processing file: C:\edi_data\test\A1991078300624.xls
# file: C:\edi_data\test\A1991078300624.xls
# file_name: A1991078300624.xls
# Extracted reporting date string: 300624 A199
# Formatted reporting date: 30-Jun-2024
# Normalized file path: C:\edi_data\test\A1991078300624.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Database error on 27: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 142, maximum: 130)
# Database error on 43: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 136, maximum: 130)
# Database error on 70: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 142, maximum: 130)
# Database error on 79: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 138, maximum: 130)
# Database error on 80: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 138, maximum: 130)
# Upserted 97 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078300624.xls
# Processing file: C:\edi_data\test\A1991078300924.xls
# file: C:\edi_data\test\A1991078300924.xls
# file_name: A1991078300924.xls
# Extracted reporting date string: 300924 A199
# Formatted reporting date: 30-Sep-2024
# Normalized file path: C:\edi_data\test\A1991078300924.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 82 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078300924.xls
# Processing file: C:\edi_data\test\A1991078301124.xls
# file: C:\edi_data\test\A1991078301124.xls
# file_name: A1991078301124.xls
# Extracted reporting date string: 301124 A199
# Formatted reporting date: 30-Nov-2024
# Normalized file path: C:\edi_data\test\A1991078301124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 65 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078301124.xls
# Processing file: C:\edi_data\test\A1991078310124.xls
# file: C:\edi_data\test\A1991078310124.xls
# file_name: A1991078310124.xls
# Extracted reporting date string: 310124 A199
# Formatted reporting date: 31-Jan-2024
# Normalized file path: C:\edi_data\test\A1991078310124.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 94 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078310124.xls
# Processing file: C:\edi_data\test\A1991078310324.xls
# file: C:\edi_data\test\A1991078310324.xls
# file_name: A1991078310324.xls
# Extracted reporting date string: 310324 A199
# Formatted reporting date: 31-Mar-2024
# Normalized file path: C:\edi_data\test\A1991078310324.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 84 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078310324.xls
# Processing file: C:\edi_data\test\A1991078310524.xls
# file: C:\edi_data\test\A1991078310524.xls
# file_name: A1991078310524.xls
# Extracted reporting date string: 310524 A199
# Formatted reporting date: 31-May-2024
# Normalized file path: C:\edi_data\test\A1991078310524.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Database error on 27: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 142, maximum: 130)
# Database error on 43: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 136, maximum: 130)
# Database error on 70: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 142, maximum: 130)
# Database error on 79: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 138, maximum: 130)
# Database error on 80: ORA-12899: value too large for column "EDI"."ITRS_URT_RECEIPTS"."DESCRIPTION" (actual: 138, maximum: 130)
# Upserted 115 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078310524.xls
# Processing file: C:\edi_data\test\A1991078310724.xls
# file: C:\edi_data\test\A1991078310724.xls
# file_name: A1991078310724.xls
# Extracted reporting date string: 310724 A199
# Formatted reporting date: 31-Jul-2024
# Normalized file path: C:\edi_data\test\A1991078310724.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 91 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078310724.xls
# Processing file: C:\edi_data\test\A1991078310824.xls
# file: C:\edi_data\test\A1991078310824.xls
# file_name: A1991078310824.xls
# Extracted reporting date string: 310824 A199
# Formatted reporting date: 31-Aug-2024
# Normalized file path: C:\edi_data\test\A1991078310824.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 218 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078310824.xls
# Processing file: C:\edi_data\test\A1991078311024.xls
# file: C:\edi_data\test\A1991078311024.xls
# file_name: A1991078311024.xls
# Extracted reporting date string: 311024 A199
# Formatted reporting date: 31-Oct-2024
# Normalized file path: C:\edi_data\test\A1991078311024.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 97 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078311024.xls
# Processing file: C:\edi_data\test\A1991078311224.xls
# file: C:\edi_data\test\A1991078311224.xls
# file_name: A1991078311224.xls
# Extracted reporting date string: 311224 A199
# Formatted reporting date: 31-Dec-2024
# Normalized file path: C:\edi_data\test\A1991078311224.xls
# Index(['DESCRIPTIONNO', 'PURPOSE', 'PU_CODE', 'COUNTRY', 'SECTOR', 'CURRENCY',
#        'AMOUNT', 'DESCRIPTION', 'REPORTINGDATE', 'STATUS', 'INSTITUTIONCODE'],
#       dtype='object')
# Upserted 126 records successfully.
# Data inserted/updated successfully from file: C:\edi_data\test\A1991078311224.xls
# Processing file: C:\edi_data\test\PA1631078310324.xls
# file: C:\edi_data\test\PA1631078310324.xls
# file_name: PA1631078310324.xls
# Extracted reporting date string: 831032 PA16
# Invalid reporting date format in file: PA1631078310324.xls
